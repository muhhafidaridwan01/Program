# %%
# Import necessary libraries
import pandas as pd
import mysql.connector
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Establish a connection to the MySQL database
cnx = mysql.connector.connect(
    user='root', 
    password='', 
    host='localhost', 
    database='nilai_peternakan'
)

# Create a cursor object
cursor = cnx.cursor()

# %%
cursor.execute("SELECT * FROM peternakan")
data = cursor.fetchall()
# Get the column names
column_names = [desc[0] for desc in cursor.description]

# %%
data_dict = [dict(zip(column_names, row)) for row in data]

# %%
df = pd.DataFrame(data_dict, columns=['nim', 'nama', 'matakuliah', 'nilai_akhir','nilai_mutu'])

# %%
TL_grades = df[df['nilai_akhir'] == 0.00]

# %%
TL_grades
# Out:
#            nim                    nama                matakuliah nilai_akhir  \
# 18   220311008  MOHAMAD DEKI KURNIAWAN                   Biologi        0.00
# 49   210311017             ALI KALMANI                  Genetika        0.00
# 133  210311017             ALI KALMANI  Reproduksi Ternak dan IB        0.00
#
#     nilai_mutu
# 18          TL
# 49          TL
# 133         TL

# %%
df = df.drop(df[df['nilai_mutu'] == 'TL'].index)

# %%
a_grades = df[df['nilai_mutu'] == 'A']

# %%
b_grades = df[df['nilai_mutu'] == 'B']

# %%
c_grades = df[df['nilai_mutu'] == 'C']

# %%
d_grades = df[df['nilai_mutu'] == 'D']

# %%
e_grades = df[df['nilai_mutu'] == 'E']

# %%
invalid_grades = df[df['nilai_mutu'] == 'TL']

# %%
invalid_grades
# Out:
# Empty DataFrame
# Columns: [nim, nama, matakuliah, nilai_akhir, nilai_mutu]
# Index: []

# %%
a_grades.head()
# Out:
#           nim                        nama                 matakuliah  \
# 2   210311003             RISNAENI ADHARI  Bahan Pakan dan Formulasi
# 4   210311005             FAIZAL DARMAWAN  Bahan Pakan dan Formulasi
# 8   210311016  ASEF THRIANA NUGRAHA PUTRA  Bahan Pakan dan Formulasi
# 10  210311018       FIRMAN ALFARIZI PUTRA  Bahan Pakan dan Formulasi
# 12  220311001    ZHANUBHA CINTA AURELLINE                    Biologi
#
#    nilai_akhir nilai_mutu
# 2        85.10          A
# 4        85.30          A
# 8        86.00          A
# 10       85.10          A
# 12       91.10          A

# %%
b_grades.head()
# Out:
#          nim                       nama                 matakuliah  \
# 0  210311001         NURWAHIDIN NUGRAHA  Bahan Pakan dan Formulasi
# 1  210311002                     HABIBI  Bahan Pakan dan Formulasi
# 3  210311004  MOHAMAD RIZKI HERDIANSYAH  Bahan Pakan dan Formulasi
# 5  210311006  DHARMAWAN YUDHA EKAPAMUJI  Bahan Pakan dan Formulasi
# 6  210311011           NUR FAUZY LUKMAN  Bahan Pakan dan Formulasi
#
#   nilai_akhir nilai_mutu
# 0       77.65          B
# 1       84.35          B
# 3       81.55          B
# 5       81.85          B
# 6       78.80          B

# %%
c_grades.head()
# Out:
#           nim                nama                 matakuliah nilai_akhir  \
# 40  210311001  NURWAHIDIN NUGRAHA                   Genetika       65.25
# 46  210311011    NUR FAUZY LUKMAN                   Genetika       68.25
# 47  210311015            ADE IMAN                   Genetika       60.00
# 52  200311001          FAJAR AMIR  Ilmu Teknologi Daging dan       66.00
# 54  200311003        NIZAM ARQOTH  Ilmu Teknologi Daging dan       69.00
#
#    nilai_mutu
# 40          C
# 46          C
# 47          C
# 52          C
# 54          C

# %%
d_grades.head()
# Out:
#          nim         nama                 matakuliah nilai_akhir nilai_mutu
# 9  210311017  ALI KALMANI  Bahan Pakan dan Formulasi       55.35          D

# %%
e_grades.head()
# Out:
#            nim         nama             matakuliah nilai_akhir nilai_mutu
# 37   210311017  ALI KALMANI  Dasar-dasar Manajemen        1.00          E
# 121  210311017  ALI KALMANI   Manajemen Agribisnis       10.00          E

# %%
total_a=df[df['nilai_mutu'] == 'A'].shape[0]

# %%
total_b=df[df['nilai_mutu'] == 'B'].shape[0]

# %%
total_c=df[df['nilai_mutu'] == 'C'].shape[0]

# %%
total_d=df[df['nilai_mutu'] == 'D'].shape[0]

# %%
total_e=df[df['nilai_mutu'] == 'E'].shape[0]

# %%
total_a
# Out:
# 68

# %%
total_b
# Out:
# 49

# %%
total_c
# Out:
# 13

# %%
total_d
# Out:
# 1

# %%
total_e
# Out:
# 2

# %%
nilai_mutu_counts = df['nilai_mutu'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
nilai_mutu_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Nilai Mutu')
plt.ylabel('Total Value')
plt.title('Total Value of Each Nilai Mutu')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
grouped_counts = df.groupby(['matakuliah', 'nilai_mutu']).size().unstack(fill_value=0)

# Plotting the bar chart for each Matakuliah
for matakuliah in grouped_counts.index:
    plt.figure(figsize=(10, 6))
    grouped_counts.loc[matakuliah].plot(kind='bar', color='skyblue')
    plt.xlabel('Nilai Mutu')
    plt.ylabel('Total Value')
    plt.title(f'Total Value of Each Nilai Mutu for {matakuliah}')
    plt.xticks(rotation=0)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
